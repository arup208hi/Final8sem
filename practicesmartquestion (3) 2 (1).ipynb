# %%
import pandas as pd
import numpy as np
import random

# %%
import pymongo
from pymongo import MongoClient

# %%
connection = MongoClient('localhost', 27017)
# Database Name
db = connection["endterm"]
 
# Collection Name
col = db["exceldatas"]
x = col.find()

for data in x:
    print(data)
# Out:
# {'_id': ObjectId('63f473e17ecd50578cbed718'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed719'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed71a'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed71b'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed71c'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed71d'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed71e'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed71f'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed720'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed721'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed722'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed723'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed724'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed725'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e17ecd50578cbed726'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed729'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed72a'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed72b'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed72c'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed72d'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed72e'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed72f'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed730'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed731'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed732'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed733'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed734'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed735'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed736'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f473e77ecd50578cbed737'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed73f'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed740'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed741'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed742'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed743'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed744'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed745'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed746'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed747'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed748'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed749'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed74a'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed74b'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed74c'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('63f47f057ecd50578cbed74d'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe0f'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe10'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe11'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe12'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe13'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe14'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe15'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe16'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe17'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe18'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe19'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe1a'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe1b'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe1c'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf06b9b9824f0efbe1d'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe20'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe21'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe22'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe23'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe24'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe25'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe26'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe27'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe28'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe29'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe2a'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe2b'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe2c'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe2d'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640fedf76b9b9824f0efbe2e'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe34'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe35'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe36'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe37'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe38'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe39'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe3a'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe3b'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe3c'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe3d'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe3e'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe3f'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe40'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe41'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('640ff05c6b9b9824f0efbe42'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e54535599'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e5453559a'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e5453559b'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e5453559c'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e5453559d'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e5453559e'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e5453559f'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e545355a0'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e545355a1'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e545355a2'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e545355a3'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e545355a4'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e545355a5'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e545355a6'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104b21e4b0971e545355a7'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9e7'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9e8'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9e9'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9ea'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9eb'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9ec'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9ed'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9ee'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9ef'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9f0'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9f1'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9f2'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9f3'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9f4'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('64104c7085820a274c7bc9f5'), 'Name of the Program': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}

# %%
df=pd.DataFrame(list(col.find()))
# df.drop
# df.to_markdown()
# df
marks_5 = df['Question'][df["Marks"]=='5']
marks_1 = df['Question'][df["Marks"]=='1']

# %%
marks_1=pd.DataFrame()
marks_1 = df['Question'][df["Marks"]=='1']
li=[]
d=marks_1.sample(n=5)
for i in d:
    li.append(i)

e=marks_5.sample(n=3)
for j in e:
    li.append(j)
df54=pd.DataFrame(li)


df54.reset_index(drop=True,inplace=True)
df54.to_html("df54.html")

data = {'Name of the program': ['Course/Subject Name:', 'Maximum Marks:','Total No. of Questions:'],
        'B.tech': ['Formal Languages and Automata Theory','50','18'],
        'Semester':['Course/Subject Code:','Time Duration:','Total No of Pages:'],
        'III':['CSE11005','3 Hrs','4']
        }

df555=pd.DataFrame(data)
df555
# Out:
#        Name of the program                                B.tech  \
# 0     Course/Subject Name:  Formal Languages and Automata Theory
# 1           Maximum Marks:                                    50
# 2  Total No. of Questions:                                    18
#
#                Semester       III
# 0  Course/Subject Code:  CSE11005
# 1        Time Duration:     3 Hrs
# 2    Total No of Pages:         4

# %%
from fpdf import FPDF 
title = '                                                                                                            '

class PDF(FPDF):
    def header(self):
        # Arial bold 15
        self.set_font('Arial', 'B', 15)
        # Calculate width of title and position
        w = self.get_string_width(title) + 0
        
        # Colors of frame, background and text

        # Title
       
        # Line break
        self.ln(10)

    def footer(self):
        # Position at 1.5 cm from bottom
        self.set_y(-15)
        # Arial italic 8
        self.set_font('Arial', 'I', 8)
        # Text color in gray
        self.set_text_color(128)
        # Page number
        self.cell(0, 10, 'Page ' + str(self.page_no()), 0, new_x=XPos.LMARGIN, new_y=YPos.NEXT)

    def chapter_title(self, num, label):
        # Arial 12
        self.set_font('Arial', '', 12)
        # Background color
        self.set_fill_color(200, 220, 255)
        # Title
        self.cell(0, 6, '                                                   ', 0, new_x=XPos.LMARGIN, new_y=YPos.NEXT)
        # Line break
        self.ln(4)

    def chapter_body(self, name):
        # Read text file
        with open(name, 'rb') as fh:
            txt = fh.read().decode('latin-1')
        # Times 12
        self.set_font('Times', '', 12)
        # Output justified text
        self.multi_cell(0, 5, txt)
        # Line break
        self.ln()
        # Mention in italics
        self.set_font('', 'I')
        self.cell(0, 5, '')

    def print_chapter(self, num, title, name):
        self.add_page()
        self.chapter_title(num, title)
        self.ln(10)
        self.chapter_body(name)

pdf = PDF()
pdf.set_title(title)
pdf.print_chapter(1, title)

pdf.output('tuto34.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8480/1012873631.py in <module>
#      58 pdf = PDF()
#      59 pdf.set_title(title)
# ---> 60 pdf.print_chapter(1, title)
#      61
#      62 pdf.output('tuto34.html')
#
# TypeError: print_chapter() missing 1 required positional argument: 'name'

# %%
print(df69)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from io import StringIO
from csv import reader
l=["5","1"]
# for i in l:
#     df2=(df1.get_group(i))
# #     print(df2)
#     print(df2[df2["Marks"]==5])
    
    
for i in df1:
    print(i)
    
#     df2=df2.drop(['_id','Paper Code','Paper Title','Name of the Program','Semester'],axis=1)
#     df69=df69.append(df2,ignore_index=True)
    
    
    
    
    
#     df3=df2['Question'].tolist()
   
    
#     if i=="1":
#         df44=random.sample(df3,5)
        
        
#     elif i=="5":    
#         df55=random.sample(df3,3)
        
# df66=''
# q=''
# co=''
# d=1
# f=1


# for i in df44:
#     df88=df2.loc[df2['Question']==i]
# #     q=df88['Course Outcome'].tolist()
# #     co=df88['Marks'].tolist()
#     df66+=(str(d)+'> '+i)+ "    "
#     d+=1
# df66+='-----------------------------------------------------------------------------------------------------------'
# q1=''
# co1=''
# for i in df55:
#     df89=df69.loc[df69['Question']==i]
#     q1=df89['Course Outcome'].tolist()
    
#     co1=df89['Marks'].tolist()
# df66+=(str(d)+'> '+i)+ "    "
# d+=1
# df66+='--------------------------------------------------------------------------------------------------------------'



    
# reader = open('stringToHtml.html','w',encoding='utf-8')
# reader.write(df66)
# Out:
# ('1',                           _id Name of the Program  \
# 0    63f473e17ecd50578cbed718                 CSE
# 1    63f473e17ecd50578cbed719                 CSE
# 2    63f473e17ecd50578cbed71a                 CSE
# 3    63f473e17ecd50578cbed71b                 CSE
# 4    63f473e17ecd50578cbed71c                 CSE
# 15   63f473e77ecd50578cbed729                 CSE
# 16   63f473e77ecd50578cbed72a                 CSE
# 17   63f473e77ecd50578cbed72b                 CSE
# 18   63f473e77ecd50578cbed72c                 CSE
# 19   63f473e77ecd50578cbed72d                 CSE
# 30   63f47f057ecd50578cbed73f                 CSE
# 31   63f47f057ecd50578cbed740                 CSE
# 32   63f47f057ecd50578cbed741                 CSE
# 33   63f47f057ecd50578cbed742                 CSE
# 34   63f47f057ecd50578cbed743                 CSE
# 45   640fedf06b9b9824f0efbe0f                 CSE
# 46   640fedf06b9b9824f0efbe10                 CSE
# 47   640fedf06b9b9824f0efbe11                 CSE
# 48   640fedf06b9b9824f0efbe12                 CSE
# 49   640fedf06b9b9824f0efbe13                 CSE
# 60   640fedf76b9b9824f0efbe20                 CSE
# 61   640fedf76b9b9824f0efbe21                 CSE
# 62   640fedf76b9b9824f0efbe22                 CSE
# 63   640fedf76b9b9824f0efbe23                 CSE
# 64   640fedf76b9b9824f0efbe24                 CSE
# 75   640ff05c6b9b9824f0efbe34                 CSE
# 76   640ff05c6b9b9824f0efbe35                 CSE
# 77   640ff05c6b9b9824f0efbe36                 CSE
# 78   640ff05c6b9b9824f0efbe37                 CSE
# 79   640ff05c6b9b9824f0efbe38                 CSE
# 90   64104b21e4b0971e54535599                 CSE
# 91   64104b21e4b0971e5453559a                 CSE
# 92   64104b21e4b0971e5453559b                 CSE
# 93   64104b21e4b0971e5453559c                 CSE
# 94   64104b21e4b0971e5453559d                 CSE
# 105  64104c7085820a274c7bc9e7                 CSE
# 106  64104c7085820a274c7bc9e8                 CSE
# 107  64104c7085820a274c7bc9e9                 CSE
# 108  64104c7085820a274c7bc9ea                 CSE
# 109  64104c7085820a274c7bc9eb                 CSE
#
#                             Paper Title Paper Code Semester  \
# 0    Switching Circuit and Logic Design   CSE11004      III
# 1    Switching Circuit and Logic Design   CSE11004      III
# 2    Switching Circuit and Logic Design   CSE11004      III
# 3    Switching Circuit and Logic Design   CSE11004      III
# 4    Switching Circuit and Logic Design   CSE11004      III
# 15   Switching Circuit and Logic Design   CSE11004      III
# 16   Switching Circuit and Logic Design   CSE11004      III
# 17   Switching Circuit and Logic Design   CSE11004      III
# 18   Switching Circuit and Logic Design   CSE11004      III
# 19   Switching Circuit and Logic Design   CSE11004      III
# 30   Switching Circuit and Logic Design   CSE11004      III
# 31   Switching Circuit and Logic Design   CSE11004      III
# 32   Switching Circuit and Logic Design   CSE11004      III
# 33   Switching Circuit and Logic Design   CSE11004      III
# 34   Switching Circuit and Logic Design   CSE11004      III
# 45   Switching Circuit and Logic Design   CSE11004      III
# 46   Switching Circuit and Logic Design   CSE11004      III
# 47   Switching Circuit and Logic Design   CSE11004      III
# 48   Switching Circuit and Logic Design   CSE11004      III
# 49   Switching Circuit and Logic Design   CSE11004      III
# 60   Switching Circuit and Logic Design   CSE11004      III
# 61   Switching Circuit and Logic Design   CSE11004      III
# 62   Switching Circuit and Logic Design   CSE11004      III
# 63   Switching Circuit and Logic Design   CSE11004      III
# 64   Switching Circuit and Logic Design   CSE11004      III
# 75   Switching Circuit and Logic Design   CSE11004      III
# 76   Switching Circuit and Logic Design   CSE11004      III
# 77   Switching Circuit and Logic Design   CSE11004      III
# 78   Switching Circuit and Logic Design   CSE11004      III
# 79   Switching Circuit and Logic Design   CSE11004      III
# 90   Switching Circuit and Logic Design   CSE11004      III
# 91   Switching Circuit and Logic Design   CSE11004      III
# 92   Switching Circuit and Logic Design   CSE11004      III
# 93   Switching Circuit and Logic Design   CSE11004      III
# 94   Switching Circuit and Logic Design   CSE11004      III
# 105  Switching Circuit and Logic Design   CSE11004      III
# 106  Switching Circuit and Logic Design   CSE11004      III
# 107  Switching Circuit and Logic Design   CSE11004      III
# 108  Switching Circuit and Logic Design   CSE11004      III
# 109  Switching Circuit and Logic Design   CSE11004      III
#
#                                               Question Course Outcome Marks  \
# 0    The output of an EX-NOR gate is 1. Which input...              1     1
# 1    The expression for Absorption law is given by:...              2     1
# 2    A variable on its own or in its complemented f...              3     1
# 3    3 bits full adder contains a)3 combinational i...              3     1
# 4    Which of the following is not a sequential cir...              2     1
# 15   The output of an EX-NOR gate is 1. Which input...              1     1
# 16   The expression for Absorption law is given by:...              2     1
# 17   A variable on its own or in its complemented f...              3     1
# 18   3 bits full adder contains a)3 combinational i...              3     1
# 19   Which of the following is not a sequential cir...              2     1
# 30   The output of an EX-NOR gate is 1. Which input...              1     1
# 31   The expression for Absorption law is given by:...              2     1
# 32   A variable on its own or in its complemented f...              3     1
# 33   3 bits full adder contains a)3 combinational i...              3     1
# 34   Which of the following is not a sequential cir...              2     1
# 45   The output of an EX-NOR gate is 1. Which input...              1     1
# 46   The expression for Absorption law is given by:...              2     1
# 47   A variable on its own or in its complemented f...              3     1
# 48   3 bits full adder contains a)3 combinational i...              3     1
# 49   Which of the following is not a sequential cir...              2     1
# 60   The output of an EX-NOR gate is 1. Which input...              1     1
# 61   The expression for Absorption law is given by:...              2     1
# 62   A variable on its own or in its complemented f...              3     1
# 63   3 bits full adder contains a)3 combinational i...              3     1
# 64   Which of the following is not a sequential cir...              2     1
# 75   The output of an EX-NOR gate is 1. Which input...              1     1
# 76   The expression for Absorption law is given by:...              2     1
# 77   A variable on its own or in its complemented f...              3     1
# 78   3 bits full adder contains a)3 combinational i...              3     1
# 79   Which of the following is not a sequential cir...              2     1
# 90   The output of an EX-NOR gate is 1. Which input...              1     1
# 91   The expression for Absorption law is given by:...              2     1
# 92   A variable on its own or in its complemented f...              3     1
# 93   3 bits full adder contains a)3 combinational i...              3     1
# 94   Which of the following is not a sequential cir...              2     1
# 105  The output of an EX-NOR gate is 1. Which input...              1     1
# 106  The expression for Absorption law is given by:...              2     1
# 107  A variable on its own or in its complemented f...              3     1
# 108  3 bits full adder contains a)3 combinational i...              3     1
# 109  Which of the following is not a sequential cir...              2     1
#
#      __v
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# 15     0
# 16     0
# 17     0
# 18     0
# 19     0
# 30     0
# 31     0
# 32     0
# 33     0
# 34     0
# 45     0
# 46     0
# 47     0
# 48     0
# 49     0
# 60     0
# 61     0
# 62     0
# 63     0
# 64     0
# 75     0
# 76     0
# 77     0
# 78     0
# 79     0
# 90     0
# 91     0
# 92     0
# 93     0
# 94     0
# 105    0
# 106    0
# 107    0
# 108    0
# 109    0  )
# ('2',                           _id Name of the Program  \
# 5    63f473e17ecd50578cbed71d                 CSE
# 6    63f473e17ecd50578cbed71e                 CSE
# 7    63f473e17ecd50578cbed71f                 CSE
# 8    63f473e17ecd50578cbed720                 CSE
# 9    63f473e17ecd50578cbed721                 CSE
# 20   63f473e77ecd50578cbed72e                 CSE
# 21   63f473e77ecd50578cbed72f                 CSE
# 22   63f473e77ecd50578cbed730                 CSE
# 23   63f473e77ecd50578cbed731                 CSE
# 24   63f473e77ecd50578cbed732                 CSE
# 35   63f47f057ecd50578cbed744                 CSE
# 36   63f47f057ecd50578cbed745                 CSE
# 37   63f47f057ecd50578cbed746                 CSE
# 38   63f47f057ecd50578cbed747                 CSE
# 39   63f47f057ecd50578cbed748                 CSE
# 50   640fedf06b9b9824f0efbe14                 CSE
# 51   640fedf06b9b9824f0efbe15                 CSE
# 52   640fedf06b9b9824f0efbe16                 CSE
# 53   640fedf06b9b9824f0efbe17                 CSE
# 54   640fedf06b9b9824f0efbe18                 CSE
# 65   640fedf76b9b9824f0efbe25                 CSE
# 66   640fedf76b9b9824f0efbe26                 CSE
# 67   640fedf76b9b9824f0efbe27                 CSE
# 68   640fedf76b9b9824f0efbe28                 CSE
# 69   640fedf76b9b9824f0efbe29                 CSE
# 80   640ff05c6b9b9824f0efbe39                 CSE
# 81   640ff05c6b9b9824f0efbe3a                 CSE
# 82   640ff05c6b9b9824f0efbe3b                 CSE
# 83   640ff05c6b9b9824f0efbe3c                 CSE
# 84   640ff05c6b9b9824f0efbe3d                 CSE
# 95   64104b21e4b0971e5453559e                 CSE
# 96   64104b21e4b0971e5453559f                 CSE
# 97   64104b21e4b0971e545355a0                 CSE
# 98   64104b21e4b0971e545355a1                 CSE
# 99   64104b21e4b0971e545355a2                 CSE
# 110  64104c7085820a274c7bc9ec                 CSE
# 111  64104c7085820a274c7bc9ed                 CSE
# 112  64104c7085820a274c7bc9ee                 CSE
# 113  64104c7085820a274c7bc9ef                 CSE
# 114  64104c7085820a274c7bc9f0                 CSE
#
#                             Paper Title Paper Code Semester  \
# 5    Switching Circuit and Logic Design   CSE11004      III
# 6    Switching Circuit and Logic Design   CSE11004      III
# 7    Switching Circuit and Logic Design   CSE11004      III
# 8    Switching Circuit and Logic Design   CSE11004      III
# 9    Switching Circuit and Logic Design   CSE11004      III
# 20   Switching Circuit and Logic Design   CSE11004      III
# 21   Switching Circuit and Logic Design   CSE11004      III
# 22   Switching Circuit and Logic Design   CSE11004      III
# 23   Switching Circuit and Logic Design   CSE11004      III
# 24   Switching Circuit and Logic Design   CSE11004      III
# 35   Switching Circuit and Logic Design   CSE11004      III
# 36   Switching Circuit and Logic Design   CSE11004      III
# 37   Switching Circuit and Logic Design   CSE11004      III
# 38   Switching Circuit and Logic Design   CSE11004      III
# 39   Switching Circuit and Logic Design   CSE11004      III
# 50   Switching Circuit and Logic Design   CSE11004      III
# 51   Switching Circuit and Logic Design   CSE11004      III
# 52   Switching Circuit and Logic Design   CSE11004      III
# 53   Switching Circuit and Logic Design   CSE11004      III
# 54   Switching Circuit and Logic Design   CSE11004      III
# 65   Switching Circuit and Logic Design   CSE11004      III
# 66   Switching Circuit and Logic Design   CSE11004      III
# 67   Switching Circuit and Logic Design   CSE11004      III
# 68   Switching Circuit and Logic Design   CSE11004      III
# 69   Switching Circuit and Logic Design   CSE11004      III
# 80   Switching Circuit and Logic Design   CSE11004      III
# 81   Switching Circuit and Logic Design   CSE11004      III
# 82   Switching Circuit and Logic Design   CSE11004      III
# 83   Switching Circuit and Logic Design   CSE11004      III
# 84   Switching Circuit and Logic Design   CSE11004      III
# 95   Switching Circuit and Logic Design   CSE11004      III
# 96   Switching Circuit and Logic Design   CSE11004      III
# 97   Switching Circuit and Logic Design   CSE11004      III
# 98   Switching Circuit and Logic Design   CSE11004      III
# 99   Switching Circuit and Logic Design   CSE11004      III
# 110  Switching Circuit and Logic Design   CSE11004      III
# 111  Switching Circuit and Logic Design   CSE11004      III
# 112  Switching Circuit and Logic Design   CSE11004      III
# 113  Switching Circuit and Logic Design   CSE11004      III
# 114  Switching Circuit and Logic Design   CSE11004      III
#
#                                               Question Course Outcome Marks  \
# 5           Give the classification of logic families.              1     2
# 6                                      Define Fan-out?              1     2
# 7                           What is propagation delay?              2     2
# 8    State the distributive property of Boolean alg...              3     2
# 9                           State De Morgan's theorem.              3     2
# 20          Give the classification of logic families.              1     2
# 21                                     Define Fan-out?              1     2
# 22                          What is propagation delay?              2     2
# 23   State the distributive property of Boolean alg...              3     2
# 24                          State De Morgan's theorem.              3     2
# 35          Give the classification of logic families.              1     2
# 36                                     Define Fan-out?              1     2
# 37                          What is propagation delay?              2     2
# 38   State the distributive property of Boolean alg...              3     2
# 39                          State De Morgan's theorem.              3     2
# 50          Give the classification of logic families.              1     2
# 51                                     Define Fan-out?              1     2
# 52                          What is propagation delay?              2     2
# 53   State the distributive property of Boolean alg...              3     2
# 54                          State De Morgan's theorem.              3     2
# 65          Give the classification of logic families.              1     2
# 66                                     Define Fan-out?              1     2
# 67                          What is propagation delay?              2     2
# 68   State the distributive property of Boolean alg...              3     2
# 69                          State De Morgan's theorem.              3     2
# 80          Give the classification of logic families.              1     2
# 81                                     Define Fan-out?              1     2
# 82                          What is propagation delay?              2     2
# 83   State the distributive property of Boolean alg...              3     2
# 84                          State De Morgan's theorem.              3     2
# 95          Give the classification of logic families.              1     2
# 96                                     Define Fan-out?              1     2
# 97                          What is propagation delay?              2     2
# 98   State the distributive property of Boolean alg...              3     2
# 99                          State De Morgan's theorem.              3     2
# 110         Give the classification of logic families.              1     2
# 111                                    Define Fan-out?              1     2
# 112                         What is propagation delay?              2     2
# 113  State the distributive property of Boolean alg...              3     2
# 114                         State De Morgan's theorem.              3     2
#
#      __v
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 20     0
# 21     0
# 22     0
# 23     0
# 24     0
# 35     0
# 36     0
# 37     0
# 38     0
# 39     0
# 50     0
# 51     0
# 52     0
# 53     0
# 54     0
# 65     0
# 66     0
# 67     0
# 68     0
# 69     0
# 80     0
# 81     0
# 82     0
# 83     0
# 84     0
# 95     0
# 96     0
# 97     0
# 98     0
# 99     0
# 110    0
# 111    0
# 112    0
# 113    0
# 114    0  )
# ('5',                           _id Name of the Program  \
# 10   63f473e17ecd50578cbed722                 CSE
# 11   63f473e17ecd50578cbed723                 CSE
# 12   63f473e17ecd50578cbed724                 CSE
# 13   63f473e17ecd50578cbed725                 CSE
# 14   63f473e17ecd50578cbed726                 CSE
# 25   63f473e77ecd50578cbed733                 CSE
# 26   63f473e77ecd50578cbed734                 CSE
# 27   63f473e77ecd50578cbed735                 CSE
# 28   63f473e77ecd50578cbed736                 CSE
# 29   63f473e77ecd50578cbed737                 CSE
# 40   63f47f057ecd50578cbed749                 CSE
# 41   63f47f057ecd50578cbed74a                 CSE
# 42   63f47f057ecd50578cbed74b                 CSE
# 43   63f47f057ecd50578cbed74c                 CSE
# 44   63f47f057ecd50578cbed74d                 CSE
# 55   640fedf06b9b9824f0efbe19                 CSE
# 56   640fedf06b9b9824f0efbe1a                 CSE
# 57   640fedf06b9b9824f0efbe1b                 CSE
# 58   640fedf06b9b9824f0efbe1c                 CSE
# 59   640fedf06b9b9824f0efbe1d                 CSE
# 70   640fedf76b9b9824f0efbe2a                 CSE
# 71   640fedf76b9b9824f0efbe2b                 CSE
# 72   640fedf76b9b9824f0efbe2c                 CSE
# 73   640fedf76b9b9824f0efbe2d                 CSE
# 74   640fedf76b9b9824f0efbe2e                 CSE
# 85   640ff05c6b9b9824f0efbe3e                 CSE
# 86   640ff05c6b9b9824f0efbe3f                 CSE
# 87   640ff05c6b9b9824f0efbe40                 CSE
# 88   640ff05c6b9b9824f0efbe41                 CSE
# 89   640ff05c6b9b9824f0efbe42                 CSE
# 100  64104b21e4b0971e545355a3                 CSE
# 101  64104b21e4b0971e545355a4                 CSE
# 102  64104b21e4b0971e545355a5                 CSE
# 103  64104b21e4b0971e545355a6                 CSE
# 104  64104b21e4b0971e545355a7                 CSE
# 115  64104c7085820a274c7bc9f1                 CSE
# 116  64104c7085820a274c7bc9f2                 CSE
# 117  64104c7085820a274c7bc9f3                 CSE
# 118  64104c7085820a274c7bc9f4                 CSE
# 119  64104c7085820a274c7bc9f5                 CSE
#
#                             Paper Title Paper Code Semester  \
# 10   Switching Circuit and Logic Design   CSE11004      III
# 11   Switching Circuit and Logic Design   CSE11004      III
# 12   Switching Circuit and Logic Design   CSE11004      III
# 13   Switching Circuit and Logic Design   CSE11004      III
# 14   Switching Circuit and Logic Design   CSE11004      III
# 25   Switching Circuit and Logic Design   CSE11004      III
# 26   Switching Circuit and Logic Design   CSE11004      III
# 27   Switching Circuit and Logic Design   CSE11004      III
# 28   Switching Circuit and Logic Design   CSE11004      III
# 29   Switching Circuit and Logic Design   CSE11004      III
# 40   Switching Circuit and Logic Design   CSE11004      III
# 41   Switching Circuit and Logic Design   CSE11004      III
# 42   Switching Circuit and Logic Design   CSE11004      III
# 43   Switching Circuit and Logic Design   CSE11004      III
# 44   Switching Circuit and Logic Design   CSE11004      III
# 55   Switching Circuit and Logic Design   CSE11004      III
# 56   Switching Circuit and Logic Design   CSE11004      III
# 57   Switching Circuit and Logic Design   CSE11004      III
# 58   Switching Circuit and Logic Design   CSE11004      III
# 59   Switching Circuit and Logic Design   CSE11004      III
# 70   Switching Circuit and Logic Design   CSE11004      III
# 71   Switching Circuit and Logic Design   CSE11004      III
# 72   Switching Circuit and Logic Design   CSE11004      III
# 73   Switching Circuit and Logic Design   CSE11004      III
# 74   Switching Circuit and Logic Design   CSE11004      III
# 85   Switching Circuit and Logic Design   CSE11004      III
# 86   Switching Circuit and Logic Design   CSE11004      III
# 87   Switching Circuit and Logic Design   CSE11004      III
# 88   Switching Circuit and Logic Design   CSE11004      III
# 89   Switching Circuit and Logic Design   CSE11004      III
# 100  Switching Circuit and Logic Design   CSE11004      III
# 101  Switching Circuit and Logic Design   CSE11004      III
# 102  Switching Circuit and Logic Design   CSE11004      III
# 103  Switching Circuit and Logic Design   CSE11004      III
# 104  Switching Circuit and Logic Design   CSE11004      III
# 115  Switching Circuit and Logic Design   CSE11004      III
# 116  Switching Circuit and Logic Design   CSE11004      III
# 117  Switching Circuit and Logic Design   CSE11004      III
# 118  Switching Circuit and Logic Design   CSE11004      III
# 119  Switching Circuit and Logic Design   CSE11004      III
#
#                                               Question Course Outcome Marks  \
# 10   Explain the process of converting SOP to SSOP ...              2     5
# 11   Explain the method of Boolean expression minim...              1     5
# 12    Explain the major properties of Boolean algebra               1     5
# 13   Classify the logic families based on its opera...              3     5
# 14         Discuss the classifications of FET devices.              2     5
# 25   Explain the process of converting SOP to SSOP ...              2     5
# 26   Explain the method of Boolean expression minim...              1     5
# 27    Explain the major properties of Boolean algebra               1     5
# 28   Classify the logic families based on its opera...              3     5
# 29         Discuss the classifications of FET devices.              2     5
# 40   Explain the process of converting SOP to SSOP ...              2     5
# 41   Explain the method of Boolean expression minim...              1     5
# 42    Explain the major properties of Boolean algebra               1     5
# 43   Classify the logic families based on its opera...              3     5
# 44         Discuss the classifications of FET devices.              2     5
# 55   Explain the process of converting SOP to SSOP ...              2     5
# 56   Explain the method of Boolean expression minim...              1     5
# 57    Explain the major properties of Boolean algebra               1     5
# 58   Classify the logic families based on its opera...              3     5
# 59         Discuss the classifications of FET devices.              2     5
# 70   Explain the process of converting SOP to SSOP ...              2     5
# 71   Explain the method of Boolean expression minim...              1     5
# 72    Explain the major properties of Boolean algebra               1     5
# 73   Classify the logic families based on its opera...              3     5
# 74         Discuss the classifications of FET devices.              2     5
# 85   Explain the process of converting SOP to SSOP ...              2     5
# 86   Explain the method of Boolean expression minim...              1     5
# 87    Explain the major properties of Boolean algebra               1     5
# 88   Classify the logic families based on its opera...              3     5
# 89         Discuss the classifications of FET devices.              2     5
# 100  Explain the process of converting SOP to SSOP ...              2     5
# 101  Explain the method of Boolean expression minim...              1     5
# 102   Explain the major properties of Boolean algebra               1     5
# 103  Classify the logic families based on its opera...              3     5
# 104        Discuss the classifications of FET devices.              2     5
# 115  Explain the process of converting SOP to SSOP ...              2     5
# 116  Explain the method of Boolean expression minim...              1     5
# 117   Explain the major properties of Boolean algebra               1     5
# 118  Classify the logic families based on its opera...              3     5
# 119        Discuss the classifications of FET devices.              2     5
#
#      __v
# 10     0
# 11     0
# 12     0
# 13     0
# 14     0
# 25     0
# 26     0
# 27     0
# 28     0
# 29     0
# 40     0
# 41     0
# 42     0
# 43     0
# 44     0
# 55     0
# 56     0
# 57     0
# 58     0
# 59     0
# 70     0
# 71     0
# 72     0
# 73     0
# 74     0
# 85     0
# 86     0
# 87     0
# 88     0
# 89     0
# 100    0
# 101    0
# 102    0
# 103    0
# 104    0
# 115    0
# 116    0
# 117    0
# 118    0
# 119    0  )

# %%
# from fpdf import FPDF
# title = 'MIDSEM QUESTION PAPER'
# from fpdf.enums import XPos, YPos

# class PDF(FPDF):
#     def create_table(self, table_data, title='', data_size = 10, title_size=12, align_data='L', align_header='L', cell_width='even', x_start='x_default',emphasize_data=[], emphasize_style=None,emphasize_color=(0,0,0)): 
#         """
#         table_data: 
#                     list of lists with first element being list of headers
#         title: 
#                     (Optional) title of table (optional)
#         data_size: 
#                     the font size of table data
#         title_size: 
#                     the font size fo the title of the table
#         align_data: 
#                     align table data
#                     L = left align
#                     C = center align
#                     R = right align
#         align_header: 
#                     align table data
#                     L = left align
#                     C = center align
#                     R = right align
#         cell_width: 
#                     even: evenly distribute cell/column width
#                     uneven: base cell size on lenght of cell/column items
#                     int: int value for width of each cell/column
#                     list of ints: list equal to number of columns with the widht of each cell / column
#         x_start: 
#                     where the left edge of table should start
#         emphasize_data:  
#                     which data elements are to be emphasized - pass as list 
#                     emphasize_style: the font style you want emphaized data to take
#                     emphasize_color: emphasize color (if other than black) 
        
#         """
#         default_style = self.font_style
#         if emphasize_style == None:
#             emphasize_style = default_style
#         # default_font = self.font_family
#         # default_size = self.font_size_pt
#         # default_style = self.font_style
#         # default_color = self.color # This does not work

#         # Get Width of Columns
#             def header(self):
#                 # Arial bold 15
#                 self.set_font('Arial', 'B', 15)
#                 # Calculate width of title and position
#                 w = self.get_string_width(title) + 6
#                 self.set_x((210 - w) / 2)
#                 # Colors of frame, background and text
#                 self.set_draw_color(0, 80, 180)
#                 self.set_fill_color(230, 230, 0)
#                 self.set_text_color(220, 50, 50)
#                 # Thickness of frame (1 mm) 
#                 self.set_line_width(1)
#                 # Title
#                 self.cell(w, 9, title, 1, new_x=XPos.LMARGIN, new_y=YPos.NEXT)
#                 # Line break
#                 self.ln(10)

#             def footer(self):
#                 # Position at 1.5 cm from bottom
#                 self.set_y(-15)
#                 # Arial italic 8
#                 self.set_font('Arial', 'I', 8)
#                 # Text color in gray
#                 self.set_text_color(128)
#                 # Page number
#                 self.cell(0, 10, 'Page ' + str(self.page_no()), 0, new_x=XPos.LMARGIN, new_y=YPos.NEXT)

#             def chapter_title(self, num, label):
#                 # Arial 12
#                 self.set_font('Arial', '', 12)
#                 # Background color
#                 self.set_fill_color(200, 220, 255)
#                 # Title
#                 self.cell(0, 6, 'Chapter %d : %s' % (num, label), 0, new_x=XPos.LMARGIN, new_y=YPos.NEXT)
#                 # Line break
#                 self.ln(4)

#             def chapter_body(self, name):
#                 # Read text file
#                 with open(name, 'rb') as fh:
#                     txt = fh.read().decode('latin-1')
#                 # Times 12
#                 self.set_font('Times', '', 12)
#                 # Output justified text
#                 self.multi_cell(0, 5, txt)
#                 # Line break
#                 self.ln()
#                 # Mention in italics
#                 self.set_font('', 'I')
#                 self.cell(0, 5, '(end of excerpt)')

#             def printing(self, num, title, name):
#                 self.add_page()
#                 self.chapter_title(num, title)
#                 self.chapter_body(name)


            
#         def get_col_widths():
#             col_width = cell_width
#             if col_width == 'even':
#                 col_width = self.epw / len(data[0]) - 1  # distribute content evenly   # epw = effective page width (width of page not including margins)
#             elif col_width == 'uneven':
#                 col_widths = []

#                 # searching through columns for largest sized cell (not rows but cols)
#                 for col in range(len(table_data[0])): # for every row
#                     longest = 0 
#                     for row in range(len(table_data)):
#                         cell_value = str(table_data[row][col])
#                         value_length = self.get_string_width(cell_value)
#                         if value_length > longest:
#                             longest = value_length
#                     col_widths.append(longest + 4) # add 4 for padding
#                 col_width = col_widths



#                         ### compare columns 

#             elif isinstance(cell_width, list):
#                 col_width = cell_width  # TODO: convert all items in list to int        
#             else:
#                 # TODO: Add try catch
#                 col_width = int(col_width)
#             return col_width

#         # Convert dict to lol
#         # Why? because i built it with lol first and added dict func after
#         # Is there performance differences?
#         if isinstance(table_data, dict):
#             header = [key for key in table_data]
#             data = []
#             for key in table_data:
#                 value = table_data[key]
#                 data.append(value)
#             # need to zip so data is in correct format (first, second, third --> not first, first, first)
#             data = [list(a) for a in zip(*data)]

#         else:
#             header = table_data[0]
#             data = table_data[1:]

#         line_height = self.font_size * 2.5

#         col_width = get_col_widths()
#         self.set_font(size=title_size)

#         # Get starting position of x
#         # Determin width of table to get x starting point for centred table
#         if x_start == 'C':
#             table_width = 0
#             if isinstance(col_width, list):
#                 for width in col_width:
#                     table_width += width
#             else: # need to multiply cell width by number of cells to get table width 
#                 table_width = col_width * len(table_data[0])
#             # Get x start by subtracting table width from pdf width and divide by 2 (margins)
#             margin_width = self.w - table_width
#             # TODO: Check if table_width is larger than pdf width

#             center_table = margin_width / 2 # only want width of left margin not both
#             x_start = center_table
#             self.set_x(x_start)
#         elif isinstance(x_start, int):
#             self.set_x(x_start)
#         elif x_start == 'x_default':
#             x_start = self.set_x(self.l_margin)


#         # TABLE CREATION #

#         # add title
#         if title != '':
#             self.multi_cell(0, line_height, title, border=0, align='j',new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
#             self.ln(line_height) # move cursor back to the left margin

#         self.set_font(size=data_size)
#         # add header
#         y1 = self.get_y()
#         if x_start:
#             x_left = x_start
#         else:
#             x_left = self.get_x()
#         x_right = self.epw + x_left
#         if  not isinstance(col_width, list):
#             if x_start:
#                 self.set_x(x_start)
#             for datum in header:
#                 self.multi_cell(col_width, line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
#                 x_right = self.get_x()
#             self.ln(line_height) # move cursor back to the left margin
#             y2 = self.get_y()
#             self.line(x_left,y1,x_right,y1)
#             self.line(x_left,y2,x_right,y2)

#             for row in data:
#                 if x_start: # not sure if I need this
#                     self.set_x(x_start)
#                 for datum in row:
#                     if datum in emphasize_data:
#                         self.set_text_color(*emphasize_color)
#                         self.set_font(style=emphasize_style)
#                         self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
#                         self.set_text_color(0,0,0)
#                         self.set_font(style=default_style)
#                     else:
#                         self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
#                 self.ln(line_height) # move cursor back to the left margin
        
#         else:
#             if x_start:
#                 self.set_x(x_start)
#             for i in range(len(header)):
#                 datum = header[i]
#                 self.multi_cell(col_width[i], line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
#                 x_right = self.get_x()
#             self.ln(line_height) # move cursor back to the left margin
#             y2 = self.get_y()
#             self.line(x_left,y1,x_right,y1)
#             self.line(x_left,y2,x_right,y2)


#             for i in range(len(data)):
#                 if x_start:
#                     self.set_x(x_start)
#                 row = data[i]
#                 for i in range(len(row)):
#                     datum = row[i]
#                     if not isinstance(datum, str):
#                         datum = str(datum)
#                     adjusted_col_width = col_width[i]
#                     if datum in emphasize_data:
#                         self.set_text_color(*emphasize_color)
#                         self.set_font(style=emphasize_style)
#                         self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
#                         self.set_text_color(0,0,0)
#                         self.set_font(style=default_style)
#                     else:
#                         self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
#                 self.ln(line_height) # move cursor back to the left margin
#         y3 = self.get_y()
#         self.line(x_left,y3,x_right,y3)

# %%
# import functools
# from functools import cached_property 
# from fpdf import FPDF
# class Sample:
#     @cached_property
#     def run(self):
#         text_file=open(r"real1.txt","w",encoding="utf-8")
#         text_file.write(df66)
#         text_file.close()
        
# pdf=FPDF()
# pdf.add_page()
# pdf.set_font('Arial',size=15)
# pdf.cell(200,10,txt="Mid sem question paper",ln=1,align='C')

# f=open(r"real1.txt","r",encoding="latin-1")

# for x in f:
#     pdf.cell(200,10,txt=x,ln=2,align="C")


# pdf.output("midsem3.pdf")

# %%
# import functools
# from functools import cached_property 
# from fpdf import FPDF
# import tempfile
# temp = tempfile.TemporaryFile()
 
# # Temporary files are stored here
# temp_dir = tempfile.gettempdir()
# text_file=open(r"real1.txt","w",encoding="utf-8")
# text_file.write(df66)
# text_file.close()
# pdf=FPDF()
# pdf.add_page()
# pdf.set_font('Arial',size=15)
# pdf.cell(200,10,txt="Mid sem question paper",ln=1,align='C')

# f=open(r"real1.txt","r",encoding="latin-1")

# for x in f:
#     pdf.cell(200,10,txt=x,ln=2,align="C")


# pdf.output("midsem4.pdf")

# %%
# Main1
from fpdf import FPDF 
from fpdf.enums import XPos, YPos

class PDF(FPDF):
    def create_table(self, table_data, title='', data_size = 10, title_size=12, align_data='L', align_header='L', cell_width='even', x_start='x_default',emphasize_data=[], emphasize_style=None,emphasize_color=(0,0,0)):
        """
        table_data:
                    list of lists with first element being list of headers
        title:
                    (Optional) title of table (optional)
        data_size:
                    the font size of table data
        title_size:
                    the font size fo the title of the table
        align_data:
                    align table data
                    L = left align
                    C = center align
                    R = right align
        align_header:
                    align table data
                    L = left align
                    C = center align
                    R = right align
        cell_width:
                    even: evenly distribute cell/column width
                    uneven: base cell size on lenght of cell/column items
                    int: int value for width of each cell/column
                    list of ints: list equal to number of columns with the widht of each cell / column
        x_start:
                    where the left edge of table should start
        emphasize_data:  
                    which data elements are to be emphasized - pass as list
                    emphasize_style: the font style you want emphaized data to take
                    emphasize_color: emphasize color (if other than black)
       
        """
        default_style = self.font_style
        if emphasize_style == None:
            emphasize_style = default_style
        # default_font = self.font_family
        # default_size = self.font_size_pt
        # default_style = self.font_style
        # default_color = self.color # This does not work

        # Get Width of Columns
        def get_col_widths():
            col_width = cell_width
            if col_width == 'even':
                col_width = self.epw / len(data[0]) - 1  # distribute content evenly   # epw = effective page width (width of page not including margins)
            elif col_width == 'uneven':
                col_widths = []

                # searching through columns for largest sized cell (not rows but cols)
                for col in range(len(table_data[0])): # for every row
                    longest = 0
                    for row in range(len(table_data)):
                        cell_value = str(table_data[row][col])
                        value_length = self.get_string_width(cell_value)
                        if value_length > longest:
                            longest = value_length
                    col_widths.append(longest + 4) # add 4 for padding
                col_width = col_widths



                        ### compare columns

            elif isinstance(cell_width, list):
                col_width = cell_width  # TODO: convert all items in list to int        
            else:
                # TODO: Add try catch
                col_width = int(col_width)
            return col_width

        # Convert dict to lol
        # Why? because i built it with lol first and added dict func after
        # Is there performance differences?
        if isinstance(table_data, dict):
            header = [key for key in table_data]
            data = []
            for key in table_data:
                value = table_data[key]
                data.append(value)
            # need to zip so data is in correct format (first, second, third --> not first, first, first)
            data = [list(a) for a in zip(*data)]

        else:
            header = table_data[0]
            data = table_data[1:]

        line_height = self.font_size * 2.5

        col_width = get_col_widths()
        self.set_font(size=title_size)

        # Get starting position of x
        # Determin width of table to get x starting point for centred table
        if x_start == 'C':
            table_width = 0
            if isinstance(col_width, list):
                for width in col_width:
                    table_width += width
            else: # need to multiply cell width by number of cells to get table width
                table_width = col_width * len(table_data[0])
            # Get x start by subtracting table width from pdf width and divide by 2 (margins)
            margin_width = self.w - table_width
            # TODO: Check if table_width is larger than pdf width

            center_table = margin_width / 2 # only want width of left margin not both
            x_start = center_table
            self.set_x(x_start)
        elif isinstance(x_start, int):
            self.set_x(x_start)
        elif x_start == 'x_default':
            x_start = self.set_x(self.l_margin)


        # TABLE CREATION #

        # add title
        if title != '':
            self.multi_cell(0, line_height, title, border=0, align='j',new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
            self.ln(line_height) # move cursor back to the left margin

        self.set_font(size=data_size)
        # add header
        y1 = self.get_y()
        if x_start:
            x_left = x_start
        else:
            x_left = self.get_x()
        x_right = self.epw + x_left
        if  not isinstance(col_width, list):
            if x_start:
                self.set_x(x_start)
            for datum in header:
                self.multi_cell(col_width, line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                x_right = self.get_x()
            self.ln(line_height) # move cursor back to the left margin
            y2 = self.get_y()
            self.line(x_left,y1,x_right,y1)
            self.line(x_left,y2,x_right,y2)

            for row in data:
                if x_start: # not sure if I need this
                    self.set_x(x_start)
                for datum in row:
                    if datum in emphasize_data:
                        self.set_text_color(*emphasize_color)
                        self.set_font(style=emphasize_style)
                        self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                        self.set_text_color(0,0,0)
                        self.set_font(style=default_style)
                    else:
                        self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
                self.ln(line_height) # move cursor back to the left margin
       
        else:
            if x_start:
                self.set_x(x_start)
            for i in range(len(header)):
                datum = header[i]
                self.multi_cell(col_width[i], line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                x_right = self.get_x()
            self.ln(line_height) # move cursor back to the left margin
            y2 = self.get_y()
            self.line(x_left,y1,x_right,y1)
            self.line(x_left,y2,x_right,y2)


            for i in range(len(data)):
                if x_start:
                    self.set_x(x_start)
                row = data[i]
                for i in range(len(row)):
                    datum = row[i]
                    if not isinstance(datum, str):
                        datum = str(datum)
                    adjusted_col_width = col_width[i]
                    if datum in emphasize_data:
                        self.set_text_color(*emphasize_color)
                        self.set_font(style=emphasize_style)
                        self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                        self.set_text_color(0,0,0)
                        self.set_font(style=default_style)
                    else:
                        self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
                self.ln(line_height) # move cursor back to the left margin
        y3 = self.get_y()
        self.line(x_left,y3,x_right,y3)
data = [
    ["Name of the program:", "B.tech", "Semester:", "III",], # 'testing','size'],
    ["Course/Subject Name:", "Formal Languages and Automata Theory", "Course/Subject Code:", "CSE11005",], # 'testing','size'],
    ["Maximum Marks:", "50", "Time Duration:", "3 Hrs",], # 'testing','size'],
    ["Total No. of Questions:", "18", "Total No of Pages:", "4",], # 'testing','size'],
     # 'testing','size'],
]




pdf = PDF()
pdf.add_page()
pdf.set_font("Times", size=10)

pdf.create_table(table_data = data,title='Mid Sem Question Paper',emphasize_data=['Name of the program','Semester','Course/Subject Name','Course/Subject Code'],emphasize_style='BIU', cell_width='even')
pdf.ln()

# %%
# Main2
import functools 
from functools import cached_property 
from fpdf import FPDF
import tempfile
temp = tempfile.TemporaryFile()
 
# Temporary files are stored here
temp_dir = tempfile.gettempdir()
text_file=open(r"real1.txt","w",encoding="utf-8")
text_file.write(df66)
text_file.close()




 
title = '                                                                                                           '

class PDF(FPDF):
    
        def create_table(self, table_data, title='', data_size = 10, title_size=12, align_data='L', align_header='L', cell_width='even', x_start='x_default',emphasize_data=[], emphasize_style=None,emphasize_color=(0,0,0)):
            """
            table_data:
                        list of lists with first element being list of headers
            title:
                        (Optional) title of table (optional)
            data_size:
                        the font size of table data
            title_size:
                        the font size fo the title of the table
            align_data:
                        align table data
                        L = left align
                        C = center align
                        R = right align
            align_header:
                        align table data
                        L = left align
                        C = center align
                        R = right align
            cell_width:
                        even: evenly distribute cell/column width
                        uneven: base cell size on lenght of cell/column items
                        int: int value for width of each cell/column
                        list of ints: list equal to number of columns with the widht of each cell / column
            x_start:
                        where the left edge of table should start
            emphasize_data:  
                        which data elements are to be emphasized - pass as list
                        emphasize_style: the font style you want emphaized data to take
                        emphasize_color: emphasize color (if other than black)

            """
            default_style = self.font_style
            if emphasize_style == None:
                emphasize_style = default_style
            # default_font = self.font_family
            # default_size = self.font_size_pt
            # default_style = self.font_style
            # default_color = self.color # This does not work

        # Get Width of Columns
        def get_col_widths():
            col_width = cell_width
            if col_width == 'even':
                col_width = self.epw / len(data[0]) - 1  # distribute content evenly   # epw = effective page width (width of page not including margins)
            elif col_width == 'uneven':
                col_widths = []

                # searching through columns for largest sized cell (not rows but cols)
                for col in range(len(table_data[0])): # for every row
                    longest = 0
                    for row in range(len(table_data)):
                        cell_value = str(table_data[row][col])
                        value_length = self.get_string_width(cell_value)
                        if value_length > longest:
                            longest = value_length
                    col_widths.append(longest + 4) # add 4 for padding
                col_width = col_widths



                        ### compare columns

            elif isinstance(cell_width, list):
                col_width = cell_width  # TODO: convert all items in list to int        
            else:
                # TODO: Add try catch
                col_width = int(col_width)
            return col_width

        # Convert dict to lol
        # Why? because i built it with lol first and added dict func after
        # Is there performance differences?
        if isinstance(table_data, dict):
            header = [key for key in table_data]
            data = []
            for key in table_data:
                value = table_data[key]
                data.append(value)
            # need to zip so data is in correct format (first, second, third --> not first, first, first)
            data = [list(a) for a in zip(*data)]

        else:
            header = table_data[0]
            data = table_data[1:]

        line_height = self.font_size * 2.5

        col_width = get_col_widths()
        self.set_font(size=title_size)

        # Get starting position of x
        # Determin width of table to get x starting point for centred table
        if x_start == 'C':
            table_width = 0
            if isinstance(col_width, list):
                for width in col_width:
                    table_width += width
            else: # need to multiply cell width by number of cells to get table width
                table_width = col_width * len(table_data[0])
            # Get x start by subtracting table width from pdf width and divide by 2 (margins)
            margin_width = self.w - table_width
            # TODO: Check if table_width is larger than pdf width

            center_table = margin_width / 2 # only want width of left margin not both
            x_start = center_table
            self.set_x(x_start)
        elif isinstance(x_start, int):
            self.set_x(x_start)
        elif x_start == 'x_default':
            x_start = self.set_x(self.l_margin)


        # TABLE CREATION #

        # add title
        if title != '':
            self.multi_cell(0, line_height, title, border=0, align='j',new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
            self.ln(line_height) # move cursor back to the left margin

        self.set_font(size=data_size)
        # add header
        y1 = self.get_y()
        if x_start:
            x_left = x_start
        else:
            x_left = self.get_x()
        x_right = self.epw + x_left
        if  not isinstance(col_width, list):
            if x_start:
                self.set_x(x_start)
            for datum in header:
                self.multi_cell(col_width, line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                x_right = self.get_x()
            self.ln(line_height) # move cursor back to the left margin
            y2 = self.get_y()
            self.line(x_left,y1,x_right,y1)
            self.line(x_left,y2,x_right,y2)

            for row in data:
                if x_start: # not sure if I need this
                    self.set_x(x_start)
                for datum in row:
                    if datum in emphasize_data:
                        self.set_text_color(*emphasize_color)
                        self.set_font(style=emphasize_style)
                        self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                        self.set_text_color(0,0,0)
                        self.set_font(style=default_style)
                    else:
                        self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
                self.ln(line_height) # move cursor back to the left margin
       
        else:
            if x_start:
                self.set_x(x_start)
            for i in range(len(header)):
                datum = header[i]
                self.multi_cell(col_width[i], line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                x_right = self.get_x()
            self.ln(line_height) # move cursor back to the left margin
            y2 = self.get_y()
            self.line(x_left,y1,x_right,y1)
            self.line(x_left,y2,x_right,y2)


            for i in range(len(data)):
                if x_start:
                    self.set_x(x_start)
                row = data[i]
                for i in range(len(row)):
                    datum = row[i]
                    if not isinstance(datum, str):
                        datum = str(datum)
                    adjusted_col_width = col_width[i]
                    if datum in emphasize_data:
                        self.set_text_color(*emphasize_color)
                        self.set_font(style=emphasize_style)
                        self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                        self.set_text_color(0,0,0)
                        self.set_font(style=default_style)
                    else:
                        self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
                self.ln(line_height) # move cursor back to the left margin
        y3 = self.get_y()
        self.line(x_left,y3,x_right,y3)



        def header(self):
            # Arial bold 15
            self.set_font('Arial', 'B', 15)
            # Calculate width of title and position
            w = self.get_string_width(title) + 0

            # Colors of frame, background and text

            # Title

            # Line break
            self.ln(10)

        def footer(self):
            # Position at 1.5 cm from bottom
            self.set_y(-15)
            # Arial italic 8
            self.set_font('Arial', 'I', 8)
            # Text color in gray
            self.set_text_color(128)
            # Page number
            self.cell(0, 10, 'Page ' + str(self.page_no()), 0, new_x=XPos.LMARGIN, new_y=YPos.NEXT)

        def chapter_title(self, num, label):
            # Arial 12
            self.set_font('Arial', '', 12)
            # Background color
            self.set_fill_color(200, 220, 255)
            # Title
            self.cell(0, 6, '                                                   ', 0, new_x=XPos.LMARGIN, new_y=YPos.NEXT)
            # Line break
            self.ln(4)

        def chapter_body(self, name):
            # Read text file
            with open(name, 'rb') as fh:
                txt = fh.read().decode('latin-1')
            # Times 12
            self.set_font('Times', '', 12)
            # Output justified text
            self.multi_cell(0, 5, txt)
            # Line break
            self.ln()
            # Mention in italics
            self.set_font('', 'I')
            self.cell(0, 5, '')

        def print_chapter(self, num, title, name):
            self.add_page()
            self.chapter_title(num, title)
            self.ln(10)
            self.chapter_body(name)







 


 

pdf = PDF()
data = [
    ["Name of the program:", "B.tech", "Semester:", "III",], # 'testing','size'],
    ["Course/Subject Name:", "Formal Languages and Automata Theory", "Course/Subject Code:", "CSE11005",], # 'testing','size'],
    ["Maximum Marks:", "50", "Time Duration:", "3 Hrs",], # 'testing','size'],
    ["Total No. of Questions:", "18", "Total No of Pages:", "4",] # 'testing','size'],
     # 'testing','size'],
]
pdf.create_table(table_data = data,title='Mid Sem Question Paper',emphasize_data=['Name of the program','Semester','Course/Subject Name','Course/Subject Code'],emphasize_style='BIU', cell_width='even')
pdf.ln()

pdf.set_font('Arial',size=15)
pdf.cell(200,10,txt="Mid sem question paper",new_x=XPos.LEFT, new_y=YPos.NEXT,align='C')

f=open(r"real1.txt","r",encoding="latin-1")

for x in f:
    pdf.print_chapter(1, title, txt=x)


pdf.output("midsem1.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25952/110070721.py in <module>
#      18 title = '                                                                                                           '
#      19
# ---> 20 class PDF(FPDF):
#      21
#      22         def create_table(self, table_data, title='', data_size = 10, title_size=12, align_data='L', align_header='L', cell_width='even', x_start='x_default',emphasize_data=[], emphasize_style=None,emphasize_color=(0,0,0)):
#
# ~\AppData\Local\Temp/ipykernel_25952/110070721.py in PDF()
#      94         # Why? because i built it with lol first and added dict func after
#      95         # Is there performance differences?
# ---> 96         if isinstance(table_data, dict):
#      97             header = [key for key in table_data]
#      98             data = []
#
# NameError: name 'table_data' is not defined

# %%
# import functools 
# from functools import cached_property 
# from fpdf import FPDF
# import tempfile
# temp = tempfile.TemporaryFile()
 
# # Temporary files are stored here
# temp_dir = tempfile.gettempdir()
# text_file=open(r"real1.txt","w",encoding="utf-8")
# text_file.write(df66)
# text_file.close()

# pdf = PDF()
# pdf.add_page()
# pdf.set_font('helvetica', 'B', 14)

# pdf.create_table(table_data = data,title='Mid Sem Question Paper',emphasize_data=['Name of the program','Semester','Course/Subject Name','Course/Subject Code'],emphasize_style='BIU', cell_width='even')
# pdf.ln()

# pdf.set_font('Arial',size=14)
# pdf.cell(200,10,txt="Mid sem question paper",ln=1,align='C')

# data = [
#     ["", "B.tech", "Semester:", "III",],

# f=open(r"real1.txt","r",encoding="latin-1")

# for x in f:
#     pdf.cell(200,10,txt=x,border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP)


# pdf.output("midsem8.pdf")

# %%
from fpdf import FPDF 
title = '                                                                                                            '

class PDF(FPDF):
    def header(self):
        # Arial bold 15
        self.set_font('Arial', 'B', 15)
        # Calculate width of title and position
        w = self.get_string_width(title) + 0
        
        # Colors of frame, background and text

        # Title
       
        # Line break
        self.ln(10)

    def footer(self):
        # Position at 1.5 cm from bottom
        self.set_y(-15)
        # Arial italic 8
        self.set_font('Arial', 'I', 8)
        # Text color in gray
        self.set_text_color(128)
        # Page number
        self.cell(0, 10, 'Page ' + str(self.page_no()), 0, new_x=XPos.LMARGIN, new_y=YPos.NEXT)

    def chapter_title(self, num, label):
        # Arial 12
        self.set_font('Arial', '', 12)
        # Background color
        self.set_fill_color(200, 220, 255)
        # Title
        self.cell(0, 6, '                                                   ', 0, new_x=XPos.LMARGIN, new_y=YPos.NEXT)
        # Line break
        self.ln(4)

    def chapter_body(self, name):
        # Read text file
        with open(name, 'rb') as fh:
            txt = fh.read().decode('latin-1')
        # Times 12
        self.set_font('Times', '', 12)
        # Output justified text
        self.multi_cell(0, 5, txt)
        # Line break
        self.ln()
        # Mention in italics
        self.set_font('', 'I')
        self.cell(0, 5, '')

    def print_chapter(self, num, title, name):
        self.add_page()
        self.chapter_title(num, title)
        self.ln(10)
        self.chapter_body(name)

pdf = PDF()
pdf.set_title(title)
pdf.print_chapter(1, title, 'midsem1.pdf')

pdf.output('tuto34.pdf')
