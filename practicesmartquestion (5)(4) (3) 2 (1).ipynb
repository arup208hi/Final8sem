# %%
import pandas as pd
import numpy as np
import random

# %%
import pymongo
from pymongo import MongoClient

# %%
connection = MongoClient('localhost', 27017)
# Database Name
db = connection["arup4"]
 
# Collection Name
col = db["exceldatas"]
x = col.find()

for data in x:
    print(data)
# Out:
# {'_id': ObjectId('6468c9d0cb5f9d50acb82635'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82636'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82637'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82638'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82639'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb8263a'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb8263b'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb8263c'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb8263d'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb8263e'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb8263f'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82640'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82641'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82642'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82643'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9d0cb5f9d50acb82644'), 'Department': 'CSE', 'Paper Title': 'CSE', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'For example, 3x \x96 5 = 16 is an equation.', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82647'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.', 'Course Outcome': '1', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82648'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'The expression for Absorption law is given by: a) A + AB = A b) A + AB = B c) AB + AA\x92 = A d) A + B = B + A', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82649'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'A variable on its own or in its complemented form is known as: a) Product Term b) Literal c) Sum Term d) Word', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb8264a'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': '3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs', 'Course Outcome': '3', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb8264b'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer', 'Course Outcome': '2', 'Marks': '1', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb8264c'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Give the classification of logic families.', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb8264d'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Define Fan-out?', 'Course Outcome': '1', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb8264e'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'What is propagation delay?', 'Course Outcome': '2', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb8264f'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'State the distributive property of Boolean algebra.', 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82650'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': "State De Morgan's theorem.", 'Course Outcome': '3', 'Marks': '2', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82651'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the process of converting SOP to SSOP and POS to SPOS.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82652'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the method of Boolean expression minimization using K MAP for 3-variable.', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82653'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Explain the major properties of Boolean algebra ', 'Course Outcome': '1', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82654'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Classify the logic families based on its operation', 'Course Outcome': '3', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82655'), 'Department': 'CSE', 'Paper Title': 'Switching Circuit and Logic Design', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'Discuss the classifications of FET devices.', 'Course Outcome': '2', 'Marks': '5', '__v': 0}
# {'_id': ObjectId('6468c9dacb5f9d50acb82656'), 'Department': 'CSE', 'Paper Title': 'CSE', 'Paper Code': 'CSE11004', 'Semester': 'III', 'Question': 'For example, 3x \x96 5 = 16 is an equation.', 'Course Outcome': '2', 'Marks': '1', '__v': 0}

# %%
df=pd.DataFrame(list(col.find()))
df.drop
# Out:
# <bound method DataFrame.drop of                          _id Department                         Paper Title  \
# 0   6468c9d0cb5f9d50acb82635        CSE  Switching Circuit and Logic Design
# 1   6468c9d0cb5f9d50acb82636        CSE  Switching Circuit and Logic Design
# 2   6468c9d0cb5f9d50acb82637        CSE  Switching Circuit and Logic Design
# 3   6468c9d0cb5f9d50acb82638        CSE  Switching Circuit and Logic Design
# 4   6468c9d0cb5f9d50acb82639        CSE  Switching Circuit and Logic Design
# 5   6468c9d0cb5f9d50acb8263a        CSE  Switching Circuit and Logic Design
# 6   6468c9d0cb5f9d50acb8263b        CSE  Switching Circuit and Logic Design
# 7   6468c9d0cb5f9d50acb8263c        CSE  Switching Circuit and Logic Design
# 8   6468c9d0cb5f9d50acb8263d        CSE  Switching Circuit and Logic Design
# 9   6468c9d0cb5f9d50acb8263e        CSE  Switching Circuit and Logic Design
# 10  6468c9d0cb5f9d50acb8263f        CSE  Switching Circuit and Logic Design
# 11  6468c9d0cb5f9d50acb82640        CSE  Switching Circuit and Logic Design
# 12  6468c9d0cb5f9d50acb82641        CSE  Switching Circuit and Logic Design
# 13  6468c9d0cb5f9d50acb82642        CSE  Switching Circuit and Logic Design
# 14  6468c9d0cb5f9d50acb82643        CSE  Switching Circuit and Logic Design
# 15  6468c9d0cb5f9d50acb82644        CSE                                 CSE
# 16  6468c9dacb5f9d50acb82647        CSE  Switching Circuit and Logic Design
# 17  6468c9dacb5f9d50acb82648        CSE  Switching Circuit and Logic Design
# 18  6468c9dacb5f9d50acb82649        CSE  Switching Circuit and Logic Design
# 19  6468c9dacb5f9d50acb8264a        CSE  Switching Circuit and Logic Design
# 20  6468c9dacb5f9d50acb8264b        CSE  Switching Circuit and Logic Design
# 21  6468c9dacb5f9d50acb8264c        CSE  Switching Circuit and Logic Design
# 22  6468c9dacb5f9d50acb8264d        CSE  Switching Circuit and Logic Design
# 23  6468c9dacb5f9d50acb8264e        CSE  Switching Circuit and Logic Design
# 24  6468c9dacb5f9d50acb8264f        CSE  Switching Circuit and Logic Design
# 25  6468c9dacb5f9d50acb82650        CSE  Switching Circuit and Logic Design
# 26  6468c9dacb5f9d50acb82651        CSE  Switching Circuit and Logic Design
# 27  6468c9dacb5f9d50acb82652        CSE  Switching Circuit and Logic Design
# 28  6468c9dacb5f9d50acb82653        CSE  Switching Circuit and Logic Design
# 29  6468c9dacb5f9d50acb82654        CSE  Switching Circuit and Logic Design
# 30  6468c9dacb5f9d50acb82655        CSE  Switching Circuit and Logic Design
# 31  6468c9dacb5f9d50acb82656        CSE                                 CSE
#
#    Paper Code Semester                                           Question  \
# 0    CSE11004      III  The output of an EX-NOR gate is 1. Which input...
# 1    CSE11004      III  The expression for Absorption law is given by:...
# 2    CSE11004      III  A variable on its own or in its complemented f...
# 3    CSE11004      III  3 bits full adder contains a)3 combinational i...
# 4    CSE11004      III  Which of the following is not a sequential cir...
# 5    CSE11004      III         Give the classification of logic families.
# 6    CSE11004      III                                    Define Fan-out?
# 7    CSE11004      III                         What is propagation delay?
# 8    CSE11004      III  State the distributive property of Boolean alg...
# 9    CSE11004      III                         State De Morgan's theorem.
# 10   CSE11004      III  Explain the process of converting SOP to SSOP ...
# 11   CSE11004      III  Explain the method of Boolean expression minim...
# 12   CSE11004      III   Explain the major properties of Boolean algebra
# 13   CSE11004      III  Classify the logic families based on its opera...
# 14   CSE11004      III        Discuss the classifications of FET devices.
# 15   CSE11004      III           For example, 3x  5 = 16 is an equation.
# 16   CSE11004      III  The output of an EX-NOR gate is 1. Which input...
# 17   CSE11004      III  The expression for Absorption law is given by:...
# 18   CSE11004      III  A variable on its own or in its complemented f...
# 19   CSE11004      III  3 bits full adder contains a)3 combinational i...
# 20   CSE11004      III  Which of the following is not a sequential cir...
# 21   CSE11004      III         Give the classification of logic families.
# 22   CSE11004      III                                    Define Fan-out?
# 23   CSE11004      III                         What is propagation delay?
# 24   CSE11004      III  State the distributive property of Boolean alg...
# 25   CSE11004      III                         State De Morgan's theorem.
# 26   CSE11004      III  Explain the process of converting SOP to SSOP ...
# 27   CSE11004      III  Explain the method of Boolean expression minim...
# 28   CSE11004      III   Explain the major properties of Boolean algebra
# 29   CSE11004      III  Classify the logic families based on its opera...
# 30   CSE11004      III        Discuss the classifications of FET devices.
# 31   CSE11004      III           For example, 3x  5 = 16 is an equation.
#
#    Course Outcome Marks  __v
# 0               1     1    0
# 1               2     1    0
# 2               3     1    0
# 3               3     1    0
# 4               2     1    0
# 5               1     2    0
# 6               1     2    0
# 7               2     2    0
# 8               3     2    0
# 9               3     2    0
# 10              2     5    0
# 11              1     5    0
# 12              1     5    0
# 13              3     5    0
# 14              2     5    0
# 15              2     1    0
# 16              1     1    0
# 17              2     1    0
# 18              3     1    0
# 19              3     1    0
# 20              2     1    0
# 21              1     2    0
# 22              1     2    0
# 23              2     2    0
# 24              3     2    0
# 25              3     2    0
# 26              2     5    0
# 27              1     5    0
# 28              1     5    0
# 29              3     5    0
# 30              2     5    0
# 31              2     1    0  >

# %%
df1=df.groupby('Marks')
df1.get_group("5")
df69=pd.DataFrame()

# %%
l=["5","1"]
for i in l:
    
    
    df2=(df1.get_group(i))
    
    
    
    df2=df2.drop(['_id','Paper Code','Paper Title','Department','Semester'],axis=1)
    df69=df69.append(df2,ignore_index=True)
    
    
    
    
    
    df3=df2['Question'].tolist()
   
    
    if i=="1":
        df44=random.sample(df3,5)
        
        
    elif i=="5":    
        df55=random.sample(df3,3)
        
df66='''                      
                                    
                                                                GROUP A(1 X 5)
                                    
'''
q=''
co=''
d=1
f=1


for i in df44:
    df88=df2.loc[df2['Question']==i]
    q=df88['Course Outcome'].tolist()
    co=df88['Marks'].tolist()
    df66+=(str(d)+'> '+str(i))+"\n"
    d+=1
df66+='''                      
                                    
                                                                GROUP B(3 X 5)
                                    
'''
q1=''
co1=''
for i in df55:
    df89=df69.loc[df69['Question']==i]
    q1=df89['Course Outcome'].tolist()
    
    co1=df89['Marks'].tolist()
    df66+=(str(d)+'> '+str(i))+"\n"
    d+=1
# df66+='--------------------------------------------------------------------------------------------------------------'

# %%
df66
# Out:
# '                      \n                                    \n                                                                GROUP A(1 X 5)\n                                    \n1> For example, 3x \x96 5 = 16 is an equation.\n2> For example, 3x \x96 5 = 16 is an equation.\n3> 3 bits full adder contains a)3 combinational inputs b) 4 combinational inputs c)6 combinational inputs d) 8 combinational inputs\n4> Which of the following is not a sequential circuit? 1)Flip-Flop 2)Counter 3)Shift register 4)Multiplexer\n5> The output of an EX-NOR gate is 1. Which input combination is correct? a) A = 1, B = 0 b) A = 0, B = 1 c) A = 0, B = 0 d) A = 0, B\x92 = 1.\n                      \n                                    \n                                                                GROUP B(3 X 5)\n                                    \n6> Discuss the classifications of FET devices.\n7> Explain the major properties of Boolean algebra \n8> Explain the process of converting SOP to SSOP and POS to SPOS.\n'

# %%
# import functools
# from functools import cached_property 
# from fpdf import FPDF
# class Sample:
#     @cached_property
#     def run(self):
#         text_file=open(r"real1.txt","w",encoding="utf-8")
#         text_file.write(df66)
#         text_file.close()
        
# pdf=FPDF()
# pdf.add_page()
# pdf.set_font('Arial',size=15)
# pdf.cell(200,10,txt="Mid sem question paper",ln=1,align='C')

# f=open(r"real1.txt","r",encoding="latin-1")

# for x in f:
#     pdf.cell(200,10,txt=x,ln=2,align="C")


# pdf.output("midsem3.pdf")

# %%
# Program ="BTech"
# Department ="CSE"
# Semester="I"
# Title ="Engineering Chemistry-SCY41106"

# %%
data1 = db["dropdowndatas"]
x = data1.find()

program = ""
department=""
name=""
sem=""
for data in x:
    print(data)
    program = data["Program"]
    department = data["Department"]
    name=data["Paper title and code"]
    sem=data["Semester"]
    

x = name.split("-")
Paper_name=x[0]
Paper_code=x[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19588/3073089322.py in <module>
#      16 x = name.split("-")
#      17 Paper_name=x[0]
# ---> 18 Paper_code=x[1]
#
# IndexError: list index out of range

# %%
from fpdf import FPDF 
from fpdf.enums import XPos, YPos

class PDF(FPDF):
    def create_table(self, table_data, title='', data_size = 10, title_size=12, align_data='L', align_header='L', cell_width='even', x_start='x_default',emphasize_data=[], emphasize_style=None,emphasize_color=(0,0,0)):
        """
        table_data:
                    list of lists with first element being list of headers
        title:
                    (Optional) title of table (optional)
        data_size:
                    the font size of table data
        title_size:
                    the font size fo the title of the table
        align_data:
                    align table data
                    L = left align
                    C = center align
                    R = right align
        align_header:
                    align table data
                    L = left align
                    C = center align
                    R = right align
        cell_width:
                    even: evenly distribute cell/column width
                    uneven: base cell size on lenght of cell/column items
                    int: int value for width of each cell/column
                    list of ints: list equal to number of columns with the widht of each cell / column
        x_start:
                    where the left edge of table should start
        emphasize_data:  
                    which data elements are to be emphasized - pass as list
                    emphasize_style: the font style you want emphaized data to take
                    emphasize_color: emphasize color (if other than black)
       
        """
        default_style = self.font_style
        if emphasize_style == None:
            emphasize_style = default_style
        # default_font = self.font_family
        # default_size = self.font_size_pt
        # default_style = self.font_style
        # default_color = self.color # This does not work

        # Get Width of Columns
        def get_col_widths():
            col_width = cell_width
            if col_width == 'even':
                col_width = self.epw / len(data[0]) - 1  # distribute content evenly   # epw = effective page width (width of page not including margins)
            elif col_width == 'uneven':
                col_widths = []

                # searching through columns for largest sized cell (not rows but cols)
                for col in range(len(table_data[0])): # for every row
                    longest = 0
                    for row in range(len(table_data)):
                        cell_value = str(table_data[row][col])
                        value_length = self.get_string_width(cell_value)
                        if value_length > longest:
                            longest = value_length
                    col_widths.append(longest + 4) # add 4 for padding
                col_width = col_widths



                        ### compare columns

            elif isinstance(cell_width, list):
                col_width = cell_width  # TODO: convert all items in list to int        
            else:
                # TODO: Add try catch
                col_width = int(col_width)
            return col_width

        # Convert dict to lol
        # Why? because i built it with lol first and added dict func after
        # Is there performance differences?
        if isinstance(table_data, dict):
            header = [key for key in table_data]
            data = []
            for key in table_data:
                value = table_data[key]
                data.append(value)
            # need to zip so data is in correct format (first, second, third --> not first, first, first)
            data = [list(a) for a in zip(*data)]

        else:
            header = table_data[0]
            data = table_data[1:]

        line_height = self.font_size * 2.5

        col_width = get_col_widths()
        self.set_font(size=title_size)

        # Get starting position of x
        # Determin width of table to get x starting point for centred table
        if x_start == 'C':
            table_width = 0
            if isinstance(col_width, list):
                for width in col_width:
                    table_width += width
            else: # need to multiply cell width by number of cells to get table width
                table_width = col_width * len(table_data[0])
            # Get x start by subtracting table width from pdf width and divide by 2 (margins)
            margin_width = self.w - table_width
            # TODO: Check if table_width is larger than pdf width

            center_table = margin_width / 2 # only want width of left margin not both
            x_start = center_table
            self.set_x(x_start)
        elif isinstance(x_start, int):
            self.set_x(x_start)
        elif x_start == 'x_default':
            x_start = self.set_x(self.l_margin)


        # TABLE CREATION #

        # add title
        if title != '':
            self.multi_cell(0, line_height, title, border=0, align='j',new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
            self.ln(line_height) # move cursor back to the left margin

        self.set_font(size=data_size)
        # add header
        y1 = self.get_y()
        if x_start:
            x_left = x_start
        else:
            x_left = self.get_x()
        x_right = self.epw + x_left
        if  not isinstance(col_width, list):
            if x_start:
                self.set_x(x_start)
            for datum in header:
                self.multi_cell(col_width, line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                x_right = self.get_x()
            self.ln(line_height) # move cursor back to the left margin
            y2 = self.get_y()
            self.line(x_left,y1,x_right,y1)
            self.line(x_left,y2,x_right,y2)

            for row in data:
                if x_start: # not sure if I need this
                    self.set_x(x_start)
                for datum in row:
                    if datum in emphasize_data:
                        self.set_text_color(*emphasize_color)
                        self.set_font(style=emphasize_style)
                        self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                        self.set_text_color(0,0,0)
                        self.set_font(style=default_style)
                    else:
                        self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
                self.ln(line_height) # move cursor back to the left margin
       
        else:
            if x_start:
                self.set_x(x_start)
            for i in range(len(header)):
                datum = header[i]
                self.multi_cell(col_width[i], line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                x_right = self.get_x()
            self.ln(line_height) # move cursor back to the left margin
            y2 = self.get_y()
            self.line(x_left,y1,x_right,y1)
            self.line(x_left,y2,x_right,y2)


            for i in range(len(data)):
                if x_start:
                    self.set_x(x_start)
                row = data[i]
                for i in range(len(row)):
                    datum = row[i]
                    if not isinstance(datum, str):
                        datum = str(datum)
                    adjusted_col_width = col_width[i]
                    if datum in emphasize_data:
                        self.set_text_color(*emphasize_color)
                        self.set_font(style=emphasize_style)
                        self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                        self.set_text_color(0,0,0)
                        self.set_font(style=default_style)
                    else:
                        self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
                self.ln(line_height) # move cursor back to the left margin
        y3 = self.get_y()
        self.line(x_left,y3,x_right,y3)
data = [
    ["Name of the program:", Program+ " " + department, "Semester:", Semester,], # 'testing','size'],
    ["Subject Name", Paper_name, "Subject Code", Paper_code], # 'testing','size'],
    ["Maximum Marks:", "20", "Time Duration:", "2 Hrs",], # 'testing','size'],
    ["Total No. of Questions:", "8", "Total No of Pages:", "2",], # 'testing','size'],
     # 'testing','size'],
]




pdf = PDF()
pdf.add_page()
pdf.set_font("Times", size=10)

pdf.create_table(table_data = data,title='Mid Sem Question Paper',emphasize_data=['Name of the program','Semester','Course/Subject Name','Course/Subject Code'],emphasize_style='BIU', cell_width='even')
pdf.ln()

# %%
# import functools
# from functools import cached_property 
# from fpdf import FPDF
# import tempfile
# temp = tempfile.TemporaryFile()
 
# # Temporary files are stored here
# temp_dir = tempfile.gettempdir()
# text_file=open(r"real1.txt","w",encoding="utf-8")
# text_file.write(df66)
# text_file.close()
# pdf=FPDF()
# pdf.add_page()
# pdf.set_font('Arial',size=15)
# pdf.cell(200,10,txt="Mid sem question paper",ln=1,align='C')

# f=open(r"real1.txt","r",encoding="latin-1")

# for x in f:
#     pdf.cell(200,10,txt=x,ln=2,align="C")


# pdf.output("midsem4.pdf")

# %%
import functools 
from functools import cached_property 
from fpdf import FPDF
import tempfile
temp = tempfile.TemporaryFile()
 
# Temporary files are stored here
# temp_dir = tempfile.gettempdir()
# text_file=open(r"real1.txt","w",encoding="utf-8")
# text_file.write(df66)
# text_file.close()

pdf = PDF()
pdf.add_page()
pdf.set_font("Times", size=10)

pdf.create_table(table_data = data,title='Mid Sem Question Paper',emphasize_data=['Name of the program','Semester','Course/Subject Name','Course/Subject Code'],emphasize_style='BIU', cell_width='even')
pdf.ln()

pdf.set_font('Arial',size=10)
# pdf.cell(200,10,txt="Mid sem question paper",ln=1,align='C')

# f=open(r"real1.txt","r",encoding="latin-1")

# for x in f:
# #     pdf.cell(200,10,txt=x,ln=2,align="C")/
#     pdf.cell(w=0,h=5,txt=x,ln=1, border=0, align='L')
pdf.multi_cell(w=0, h=5, border=0, txt=df66)
pdf.cell(w=0, h=5, border=0, txt="----------------- The End -----------------", align = "C")

pdf.output("midsem43.pdf")
# Out:
# C:\Users\dasar\Anaconda3\lib\site-packages\fpdf\fpdf.py:1887: UserWarning: Substituting font arial by core font helvetica
#   warnings.warn(

# %%
# import functools 
# from functools import cached_property 
# from fpdf import FPDF
# import tempfile
# temp = tempfile.TemporaryFile()
 
# # Temporary files are stored here
# temp_dir = tempfile.gettempdir()
# text_file=open(r"real1.txt","w",encoding="utf-8")
# text_file.write(df66)
# text_file.close()

# pdf = PDF()
# pdf.add_page()
# pdf.set_font('helvetica', 'B', 14)

# pdf.create_table(table_data = data,title='Mid Sem Question Paper',emphasize_data=['Name of the program','Semester','Course/Subject Name','Course/Subject Code'],emphasize_style='BIU', cell_width='even')
# pdf.ln()

# pdf.set_font('Arial',size=14)
# pdf.cell(200,10,txt="Mid sem question paper",ln=1,align='C')

# data = [
#     ["", "B.tech", "Semester:", "III",],

# f=open(r"real1.txt","r",encoding="latin-1")

# for x in f:
#     pdf.cell(200,10,txt=x,border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP)


# pdf.output("midsem8.pdf")

# %%
import pandas as pd
import numpy as np
import random
import pymongo
from pymongo import MongoClient
connection = MongoClient('localhost', 27017)
# Database Name
db = connection["arup4"]
 
# Collection Name
col = db["exceldatas"]
df=pd.DataFrame(list(col.find()))
df.drop
df1=df.groupby('Marks')
df1.get_group("5")
df69=pd.DataFrame()
l=["5","1"]
for i in l:
    
    
    df2=(df1.get_group(i))
    
    
    
    df2=df2.drop(['_id','Paper Code','Paper Title','Department','Semester'],axis=1)
    df69=df69.append(df2,ignore_index=True)
    
    
    
    
    
    df3=df2['Question'].tolist()
   
    
    if i=="1":
        df44=random.sample(df3,5)
        
        
    elif i=="5":    
        df55=random.sample(df3,3)
        
df66='''                      
                                    
                                                                GROUP A(1 X 5)
                                    
'''
q=''
co=''
d=1
f=1


for i in df44:
    df88=df2.loc[df2['Question']==i]
    q=df88['Course Outcome'].tolist()
    co=df88['Marks'].tolist()
    df66+=(str(d)+'> '+str(i))+"\n"
    d+=1
df66+='''                      
                                    
                                                                GROUP B(3 X 5)
                                    
'''
q1=''
co1=''
for i in df55:
    df89=df69.loc[df69['Question']==i]
    q1=df89['Course Outcome'].tolist()
    
    co1=df89['Marks'].tolist()
    df66+=(str(d)+'> '+str(i))+"\n"
    d+=1
# df66+='--------------------------------------------------------------------------------------------------------------'

    
 
    




        

    
data1 = db["dropdowndatas"]
x = data1.find()

program = ""
department=""
name=""
sem=""
for data in x:
    
    program = data["Program"]
    department = data["Department"]
    name=data["Paper title and code"]
    sem=data["Semester"]
    

x = name.split("-")
Paper_name=x[0]
Paper_code=x[1]

from fpdf import FPDF 
from fpdf.enums import XPos, YPos

class PDF(FPDF):
    def create_table(self, table_data, title='', data_size = 10, title_size=12, align_data='L', align_header='L', cell_width='even', x_start='x_default',emphasize_data=[], emphasize_style=None,emphasize_color=(0,0,0)):
        """
        table_data:
                    list of lists with first element being list of headers
        title:
                    (Optional) title of table (optional)
        data_size:
                    the font size of table data
        title_size:
                    the font size fo the title of the table
        align_data:
                    align table data
                    L = left align
                    C = center align
                    R = right align
        align_header:
                    align table data
                    L = left align
                    C = center align
                    R = right align
        cell_width:
                    even: evenly distribute cell/column width
                    uneven: base cell size on lenght of cell/column items
                    int: int value for width of each cell/column
                    list of ints: list equal to number of columns with the widht of each cell / column
        x_start:
                    where the left edge of table should start
        emphasize_data:  
                    which data elements are to be emphasized - pass as list
                    emphasize_style: the font style you want emphaized data to take
                    emphasize_color: emphasize color (if other than black)
       
        """
        default_style = self.font_style
        if emphasize_style == None:
            emphasize_style = default_style
        # default_font = self.font_family
        # default_size = self.font_size_pt
        # default_style = self.font_style
        # default_color = self.color # This does not work

        # Get Width of Columns
        def get_col_widths():
            col_width = cell_width
            if col_width == 'even':
                col_width = self.epw / len(data[0]) - 1  # distribute content evenly   # epw = effective page width (width of page not including margins)
            elif col_width == 'uneven':
                col_widths = []

                # searching through columns for largest sized cell (not rows but cols)
                for col in range(len(table_data[0])): # for every row
                    longest = 0
                    for row in range(len(table_data)):
                        cell_value = str(table_data[row][col])
                        value_length = self.get_string_width(cell_value)
                        if value_length > longest:
                            longest = value_length
                    col_widths.append(longest + 4) # add 4 for padding
                col_width = col_widths



                        ### compare columns

            elif isinstance(cell_width, list):
                col_width = cell_width  # TODO: convert all items in list to int        
            else:
                # TODO: Add try catch
                col_width = int(col_width)
            return col_width

        # Convert dict to lol
        # Why? because i built it with lol first and added dict func after
        # Is there performance differences?
        if isinstance(table_data, dict):
            header = [key for key in table_data]
            data = []
            for key in table_data:
                value = table_data[key]
                data.append(value)
            # need to zip so data is in correct format (first, second, third --> not first, first, first)
            data = [list(a) for a in zip(*data)]

        else:
            header = table_data[0]
            data = table_data[1:]

        line_height = self.font_size * 2.5

        col_width = get_col_widths()
        self.set_font(size=title_size)

        # Get starting position of x
        # Determin width of table to get x starting point for centred table
        if x_start == 'C':
            table_width = 0
            if isinstance(col_width, list):
                for width in col_width:
                    table_width += width
            else: # need to multiply cell width by number of cells to get table width
                table_width = col_width * len(table_data[0])
            # Get x start by subtracting table width from pdf width and divide by 2 (margins)
            margin_width = self.w - table_width
            # TODO: Check if table_width is larger than pdf width

            center_table = margin_width / 2 # only want width of left margin not both
            x_start = center_table
            self.set_x(x_start)
        elif isinstance(x_start, int):
            self.set_x(x_start)
        elif x_start == 'x_default':
            x_start = self.set_x(self.l_margin)


        # TABLE CREATION #

        # add title
        if title != '':
            self.multi_cell(0, line_height, title, border=0, align='j',new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
            self.ln(line_height) # move cursor back to the left margin

        self.set_font(size=data_size)
        # add header
        y1 = self.get_y()
        if x_start:
            x_left = x_start
        else:
            x_left = self.get_x()
        x_right = self.epw + x_left
        if  not isinstance(col_width, list):
            if x_start:
                self.set_x(x_start)
            for datum in header:
                self.multi_cell(col_width, line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                x_right = self.get_x()
            self.ln(line_height) # move cursor back to the left margin
            y2 = self.get_y()
            self.line(x_left,y1,x_right,y1)
            self.line(x_left,y2,x_right,y2)

            for row in data:
                if x_start: # not sure if I need this
                    self.set_x(x_start)
                for datum in row:
                    if datum in emphasize_data:
                        self.set_text_color(*emphasize_color)
                        self.set_font(style=emphasize_style)
                        self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                        self.set_text_color(0,0,0)
                        self.set_font(style=default_style)
                    else:
                        self.multi_cell(col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
                self.ln(line_height) # move cursor back to the left margin
       
        else:
            if x_start:
                self.set_x(x_start)
            for i in range(len(header)):
                datum = header[i]
                self.multi_cell(col_width[i], line_height, datum, border=0, align=align_header,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                x_right = self.get_x()
            self.ln(line_height) # move cursor back to the left margin
            y2 = self.get_y()
            self.line(x_left,y1,x_right,y1)
            self.line(x_left,y2,x_right,y2)


            for i in range(len(data)):
                if x_start:
                    self.set_x(x_start)
                row = data[i]
                for i in range(len(row)):
                    datum = row[i]
                    if not isinstance(datum, str):
                        datum = str(datum)
                    adjusted_col_width = col_width[i]
                    if datum in emphasize_data:
                        self.set_text_color(*emphasize_color)
                        self.set_font(style=emphasize_style)
                        self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size)
                        self.set_text_color(0,0,0)
                        self.set_font(style=default_style)
                    else:
                        self.multi_cell(adjusted_col_width, line_height, datum, border=0, align=align_data,new_x=XPos.RIGHT, new_y=YPos.TOP, max_line_height=self.font_size) # ln = 3 - move cursor to right with same vertical offset # this uses an object named self
                self.ln(line_height) # move cursor back to the left margin
        y3 = self.get_y()
        self.line(x_left,y3,x_right,y3)
data = [
    ["Name of the program:", program+ " " + department, "Semester:", sem,], # 'testing','size'],
    ["Subject Name", Paper_name, "Subject Code", Paper_code], 
    ["Maximum Marks:", "20", "Time Duration:", "2 Hrs",], 
    ["Total No. of Questions:", "8", "Total No of Pages:", "2",],
    
]




pdf = PDF()
pdf.add_page()
pdf.set_font("Times", size=10)

pdf.create_table(table_data = data,title='Mid Sem Question Paper',emphasize_data=['Name of the program','Semester','Course/Subject Name','Course/Subject Code'],emphasize_style='BIU', cell_width='even')
pdf.ln()
import functools 
from functools import cached_property 
from fpdf import FPDF
import tempfile
temp = tempfile.TemporaryFile()
 


pdf = PDF()
pdf.add_page()
pdf.set_font("Times", size=10)

pdf.create_table(table_data = data,title='Mid Sem Question Paper',emphasize_data=['Name of the program','Semester','Course/Subject Name','Course/Subject Code'],emphasize_style='BIU', cell_width='even')
pdf.ln()

pdf.set_font('Arial',size=10)

pdf.multi_cell(w=0, h=5, border=0, txt=df66)
pdf.cell(w=0, h=5, border=0, txt="----------------- The End -----------------", align = "C")

pdf.output("midsem45.pdf")
# Out:
# C:\Users\dasar\Anaconda3\lib\site-packages\fpdf\fpdf.py:1887: UserWarning: Substituting font arial by core font helvetica
#   warnings.warn(
